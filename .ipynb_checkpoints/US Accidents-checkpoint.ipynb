# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
# import plotly.express as px
# import plotly.graph_objects as go
# from datetime import datetime
import folium
from shapely.geometry import Point
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('data/NY_Accidents.csv')
# pd.to_datetime(df[['Start_Time']], format="%Y/%m/%d")

# %%
df["coordinates"] = list(zip(df.End_Lng, df.End_Lat))
df["coordinates"] = df["coordinates"].apply(Point)
gdf = gpd.GeoDataFrame(df, geometry="coordinates")
gdf.head()
# Out:
#         ID  Severity        Start_Time          End_Time  Start_Lat  \
# 0  A-31581         2  30/11/2016 15:58  30/11/2016 21:58  40.850020
# 1  A-31608         2  30/11/2016 17:13  30/11/2016 23:13  41.311771
# 2  A-31610         2  30/11/2016 17:12  30/11/2016 23:12  43.039261
# 3  A-31626         2  30/11/2016 17:31  30/11/2016 23:31  40.771460
# 4  A-31627         2  30/11/2016 17:31  30/11/2016 23:31  40.698450
#
#    Start_Lng   End_Lat   End_Lng  Distance(mi)  \
# 0 -73.943990  40.85329 -73.96064         0.899
# 1 -74.121299  41.12997 -74.16773        12.791
# 2 -76.142130  43.04273 -76.14244         0.240
# 3 -73.946580  40.76878 -73.94906         0.226
# 4 -73.983030  40.69946 -73.98415         0.091
#
#                                          Description  Number  \
# 0  Between Amsterdam Ave/Harlem River Dr and Huds...     NaN
# 1  Between RT-17/Toll Plaza/Exit 16 and RT-17/RT-...     NaN
# 2                    At Adams St/Exit 18 - Accident.     NaN
# ...

# %%
missing_data=df.isna().sum().sort_values(ascending=False) / len(df) * 100
missing_data
# Out:
# Number                   76.856194
# Precipitation(in)        23.494899
# Wind_Chill(F)            21.942082
# Wind_Speed(mph)           4.215462
# Wind_Direction            1.484484
# Visibility(mi)            1.145173
# Weather_Condition         0.749311
# Humidity(%)               0.725748
# Temperature(F)            0.699828
# Pressure(in)              0.657414
# Weather_Timestamp         0.487759
# Airport_Code              0.197931
# Sunrise_Sunset            0.164943
# Civil_Twilight            0.164943
# Nautical_Twilight         0.164943
# Astronomical_Twilight     0.164943
# City                      0.032989
# Zipcode                   0.004713
# Timezone                  0.004713
# Give_Way                  0.000000
# No_Exit                   0.000000
# Junction                  0.000000
# Bump                      0.000000
# Railway                   0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# ...

# %%
missing_data[missing_data!=0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# fig = go.Figure(
#         data=go.Scattergeo(
#         lon = df['Start_Lng'],
#         lat = df['Start_Lat'],
#         text = df['Description'],
#         mode = 'markers',
#         marker_color = df['Severity'],
#         ))

# fig.update_layout(
#         title = 'Car Accidents in NY',
#         geo_scope='usa',
#     )
# fig.show()

# %%
df.keys()
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'coordinates'],
#       dtype='object')

# %%
ny_df=gpd.read_file("data/geodata/NYS_Civil_Boundaries.shp/Counties_Shoreline.shp")
ny_df.sample(2)
# Out:
#       NAME ABBREV GNIS_ID FIPS_CODE    SWIS    NYSP_ZONE  POP1990  POP2000  \
# 27  Monroe   MONR  974126     36055  260000         West   713968   735343
# 40  Queens   QUEE  974139     36081  630000  Long Island  1951598  2229379
#
#     POP2010  POP2020 DOS_LL DOSLL_DATE NYC  CALC_SQ_MI     DATEMOD  \
# 27   744344   759443   None       None   N  666.225694  2017-12-22
# 40  2230722  2405464   None       None   Y  109.054801  2019-10-04
#
#        Shape_Leng    Shape_Area  \
# 27  212710.850808  1.725517e+09
# 40  221028.003347  2.824506e+08
#
#                                              geometry
# 27  MULTIPOLYGON (((276475.027 4802090.668, 276475...
# 40  MULTIPOLYGON (((598509.049 4494373.339, 598537...

# %%
gdf.head()
# Out:
#         ID  Severity        Start_Time          End_Time  Start_Lat  \
# 0  A-31581         2  30/11/2016 15:58  30/11/2016 21:58  40.850020
# 1  A-31608         2  30/11/2016 17:13  30/11/2016 23:13  41.311771
# 2  A-31610         2  30/11/2016 17:12  30/11/2016 23:12  43.039261
# 3  A-31626         2  30/11/2016 17:31  30/11/2016 23:31  40.771460
# 4  A-31627         2  30/11/2016 17:31  30/11/2016 23:31  40.698450
#
#    Start_Lng   End_Lat   End_Lng  Distance(mi)  \
# 0 -73.943990  40.85329 -73.96064         0.899
# 1 -74.121299  41.12997 -74.16773        12.791
# 2 -76.142130  43.04273 -76.14244         0.240
# 3 -73.946580  40.76878 -73.94906         0.226
# 4 -73.983030  40.69946 -73.98415         0.091
#
#                                          Description  Number  \
# 0  Between Amsterdam Ave/Harlem River Dr and Huds...     NaN
# 1  Between RT-17/Toll Plaza/Exit 16 and RT-17/RT-...     NaN
# 2                    At Adams St/Exit 18 - Accident.     NaN
# ...

# %%
fig, gax = plt.subplots(figsize=(18, 18))
ny_df.plot(ax=gax, edgecolor="black", color="ghostwhite");
gdf.plot(ax=gax, color='green')
# Out:
# <AxesSubplot:>

# %%
df.sample()
# Out:
#              ID  Severity        Start_Time          End_Time  Start_Lat  \
# 13882  A-287498         2  10/05/2021 16:09  10/05/2021 17:53  43.183168
#
#        Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 13882 -75.334249  43.198498 -75.370889         2.128
#
#                                              Description  Number   Street  \
# 13882  Incident on RT-49 WB near ONEIDA COUNTY Expect...     NaN  NY-49 W
#
#       Side   City  County State Zipcode Country    Timezone Airport_Code  \
# 13882    R  Marcy  Oneida    NY   13403      US  US/Eastern         KRME
#
#       Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 13882  10/05/2021 15:53            55.0           55.0         55.0
#
#        Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 13882          29.4            10.0              W              9.0
#
#        Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# ...

# %%
map = folium.Map(location=[42.8, -75.1], 
                 tiles="Stamen Terrain", 
                 zoom_start=7)
folium.GeoJson(data=ny_df["geometry"]).add_to(map)

for i,row in gdf.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame(str(row["ID"]))
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width= 300, max_width=600)
    #Add each row to the map
    folium.Marker(location=[row['End_Lat'],row['End_Lng']],
                  popup = popup).add_to(map)

folium.LayerControl().add_to(map)
map
